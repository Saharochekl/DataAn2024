# %%
#Андан 01.03.2024

# %% [markdown]
# Задача №1

# %%
import random

import scipy
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import math

import sns
from scipy.stats import bws_test

X1_50 = np.random.uniform(0, 1, 50)
X2_50 = np.random.uniform(-10, 10, 50)
X1_100 = np.random.uniform(0, 1, 100)
X2_100 = np.random.uniform(-10, 10, 100)

Y11_50 = []
Y12_50 = []
Y13_50 = []

Y11_100 = []
Y12_100 = []
Y13_100 = []

Y21_50 = []
Y22_50 = []
Y23_50 = []

Y21_100 = []
Y22_100 = []
Y23_100 = []

U_50 = np.random.uniform(-2, 2, 50)
U_100 = np.random.uniform(-2, 2, 100)

for i in range(50):
    Y11_50.append(2*X1_50[i] + 5 + U_50[i])
    Y12_50.append(X1_50[i]**2 + U_50[i])
    Y13_50.append(X1_50[i]*math.cos(X1_50[i]) + U_50[i])
    Y21_50.append(2*X2_50[i] + 5 + U_50[i])
    Y22_50.append(X2_50[i]**2 + U_50[i])
    Y23_50.append(X2_50[i]*math.cos(X2_50[i]) + U_50[i])

for i in range(100):
    Y11_100.append(2*X1_100[i] + 5 + U_100[i])
    Y12_100.append(X1_100[i]**2 + U_100[i])
    Y13_100.append(X1_100[i]*math.cos(X1_100[i]) + U_100[i])
    Y21_100.append(2*X2_100[i] + 5 + U_100[i])
    Y22_100.append(X2_100[i]**2 + U_100[i])
    Y23_100.append(X2_100[i]*math.cos(X2_100[i]) + U_100[i])
    
test1 = scipy.stats.pearsonr(X1_50, Y11_50)
test2 = scipy.stats.pearsonr(X1_100, Y11_100)
print("Пирсон X~R[0;1] f(x) = 2x+5 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.pearsonr(X1_50, Y12_50)
test2 = scipy.stats.pearsonr(X1_100, Y12_100)
print("Пирсон X~R[0;1] f(x) = x^2 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.pearsonr(X1_50, Y13_50)
test2 = scipy.stats.pearsonr(X1_100, Y13_100)
print("Пирсон X~R[0;1] f(x) = x*cos(x) : \n",test1, "\n", test2, "\n")

#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------

test1 = scipy.stats.pearsonr(X2_50, Y21_50)
test2 = scipy.stats.pearsonr(X2_100, Y21_100)
print("Пирсон X~R[-10;10] f(x) = 2x+5 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.pearsonr(X2_50, Y22_50)
test2 = scipy.stats.pearsonr(X2_100, Y22_100)
print("Пирсон X~R[-10;10] f(x) = x^2 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.pearsonr(X2_50, Y23_50)
test2 = scipy.stats.pearsonr(X2_100, Y23_100)
print("Пирсон X~R[-10;10] f(x) = x*cos(x) : \n",test1, "\n", test2, "\n")

#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------



test1 = scipy.stats.spearmanr(X1_50, Y11_50)
test2 = scipy.stats.spearmanr(X1_100, Y11_100)
print("Спирмена X~R[0;1] f(x) = 2x+5 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.spearmanr(X1_50, Y12_50)
test2 = scipy.stats.spearmanr(X1_100, Y12_100)
print("Спирмена X~R[0;1] f(x) = x^2 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.spearmanr(X1_50, Y13_50)
test2 = scipy.stats.spearmanr(X1_100, Y13_100)
print("Спирмена X~R[0;1] f(x) = x*cos(x) : \n",test1, "\n", test2, "\n")

#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------

test1 = scipy.stats.spearmanr(X2_50, Y21_50)
test2 = scipy.stats.spearmanr(X2_100, Y21_100)
print("Спирмена X~R[-10;10] f(x) = 2x+5 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.spearmanr(X2_50, Y22_50)
test2 = scipy.stats.spearmanr(X2_100, Y22_100)
print("Спирмена X~R[-10;10] f(x) = x^2 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.spearmanr(X2_50, Y23_50)
test2 = scipy.stats.spearmanr(X2_100, Y23_100)
print("Спирмена X~R[-10;10] f(x) = x*cos(x) : \n",test1, "\n", test2, "\n")

#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------



test1 = scipy.stats.kendalltau(X1_50, Y11_50)
test2 = scipy.stats.kendalltau(X1_100, Y11_100)
print("Кенделл X~R[0;1] f(x) = 2x+5 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.kendalltau(X1_50, Y12_50)
test2 = scipy.stats.kendalltau(X1_100, Y12_100)
print("Кенделл X~R[0;1] f(x) = x^2 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.kendalltau(X1_50, Y13_50)
test2 = scipy.stats.kendalltau(X1_100, Y13_100)
print("Кенделл X~R[0;1] f(x) = x*cos(x) : \n",test1, "\n", test2, "\n")

#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------

test1 = scipy.stats.kendalltau(X2_50, Y21_50)
test2 = scipy.stats.kendalltau(X2_100, Y21_100)
print("Кенделл X~R[-10;10] f(x) = 2x+5 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.kendalltau(X2_50, Y22_50)
test2 = scipy.stats.kendalltau(X2_100, Y22_100)
print("Кенделл X~R[-10;10] f(x) = x^2 : \n",test1, "\n", test2, "\n")

test1 = scipy.stats.kendalltau(X2_50, Y23_50)
test2 = scipy.stats.kendalltau(X2_100, Y23_100)
print("Кенделл X~R[-10;10] f(x) = x*cos(x) : \n",test1, "\n", test2, "\n")

#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------

test1 = scipy.stats.multiscale_graphcorr(np.array(X1_50), np.array(Y11_50))
test2 = scipy.stats.multiscale_graphcorr(np.array(X1_100), np.array(Y11_100))
print("MGC X~R[0;1] f(x) = 2x+5 : \n",test1.pvalue, "\n", test2.pvalue, "\n")

test1 = scipy.stats.multiscale_graphcorr(np.array(X1_50), np.array(Y12_50))
test2 = scipy.stats.multiscale_graphcorr(np.array(X1_100), np.array(Y12_100))
print("MGC X~R[0;1] f(x) = x^2 : \n",test1.pvalue, "\n", test2.pvalue, "\n")

test1 = scipy.stats.multiscale_graphcorr(np.array(X1_50), np.array(Y13_50))
test2 = scipy.stats.multiscale_graphcorr(np.array(X1_100), np.array(Y13_100))
print("MGC X~R[0;1] f(x) = x*cos(x) : \n",test1.pvalue, "\n", test2.pvalue, "\n")

#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------

test1 = scipy.stats.multiscale_graphcorr(np.array(X2_50), np.array(Y21_50))
test2 = scipy.stats.multiscale_graphcorr(np.array(X2_100), np.array(Y21_100))
print("MGC X~R[-10;10] f(x) = 2x+5 : \n",test1.pvalue, "\n", test2.pvalue, "\n")

test1 = scipy.stats.multiscale_graphcorr(np.array(X2_50), np.array(Y22_50))
test2 = scipy.stats.multiscale_graphcorr(np.array(X2_100), np.array(Y22_100))
print("MGC X~R[-10;10] f(x) = x^2 : \n",test1.pvalue, "\n", test2.pvalue, "\n")

test1 = scipy.stats.multiscale_graphcorr(np.array(X2_50), np.array(Y23_50))
test2 = scipy.stats.multiscale_graphcorr(np.array(X2_100), np.array(Y23_100))
print("MGC X~R[-10;10] f(x) = x*cos(x) : \n",test1.pvalue, "\n", test2.pvalue, "\n")
# Out:
# Пирсон X~R[0;1] f(x) = 2x+5 :
#  PearsonRResult(statistic=0.4968573962355706, pvalue=0.00024227958776336936)
#  PearsonRResult(statistic=0.4557602368589728, pvalue=1.8895681736863048e-06)
#
# Пирсон X~R[0;1] f(x) = x^2 :
#  PearsonRResult(statistic=0.2797176013765577, pvalue=0.049143803700433045)
#  PearsonRResult(statistic=0.23933976837863352, pvalue=0.016472551532839507)
#
# Пирсон X~R[0;1] f(x) = x*cos(x) :
#  PearsonRResult(statistic=0.17357351461383597, pvalue=0.2280169766487224)
#  PearsonRResult(statistic=0.14157735787388737, pvalue=0.160002823731624)
#
# Пирсон X~R[-10;10] f(x) = 2x+5 :
#  PearsonRResult(statistic=0.9947765019862129, pvalue=3.0887089636049363e-49)
#  PearsonRResult(statistic=0.9956734108854062, pvalue=6.06157546479892e-103)
#
# Пирсон X~R[-10;10] f(x) = x^2 :
#  PearsonRResult(statistic=-0.02729345580300085, pvalue=0.8507610416533351)
#  PearsonRResult(statistic=0.12182432110841876, pvalue=0.22726658669321922)
#
# Пирсон X~R[-10;10] f(x) = x*cos(x) :
# ...

# %% [markdown]
# Задача №2

# %%
import hyppo
import scipy
import numpy as np
import random
import scipy.stats as sps
import matplotlib.pyplot as plt
import math
from scipy.stats import bws_test
pi = math.pi

#Делаем Кольцо
phi1_50 = np.random.uniform(0, 2*pi, 50)
phi1_100 = np.random.uniform(0, 2*pi, 100)

r1_50 = np.random.uniform(1/math.sqrt(2), 1, 50)
r1_100 = np.random.uniform(1/math.sqrt(2), 1, 100)

X1_50 = []
X3_50 = []
X1_100 = []
X3_100 = []
Y1_50 = []
Y3_50 = []
Y1_100 = []
Y3_100 = []

for i in range(50):
    X1_50.append(r1_50[i]*math.cos(phi1_50[i]))
    Y1_50.append(r1_50[i]*math.sin(phi1_50[i]))

for i in range(100):
    X1_100.append(r1_100[i]*math.cos(phi1_100[i]))
    Y1_100.append(r1_100[i]*math.sin(phi1_100[i]))
#Создаём Квадрат
X2_50 = np.random.uniform(-1, 1, 50)
X2_100 = np.random.uniform(-1, 1, 100)
Y2_50 = np.random.uniform(-1, 1, 50)
Y2_100 = np.random.uniform(-1, 1, 100)

#Создаём 4 круга
for i in range(50):
    fl = random.randint(1, 2)
    flx = pow(-1, fl)
    fl = random.randint(1, 2)
    fly = pow(-1, fl)
    phi1_50 = np.random.uniform(0, 2*pi)
    r1_50 = np.random.uniform(0, 1/2)
    X3_50.append(r1_50*math.cos(phi1_50)+ flx)
    Y3_50.append(r1_50*math.sin(phi1_50)+ fly)

for i in range(100):
    fl = random.randint(1, 2)
    flx = pow(-1, fl)
    fl = random.randint(1, 2)
    fly = pow(-1, fl)
    phi1_100 = np.random.uniform(0, 2*pi)
    r1_100 = np.random.uniform(0, 1/2)
    X3_100.append(r1_100*math.cos(phi1_100) + flx)
    Y3_100.append(r1_100*math.sin(phi1_100)+ fly)

#----------------------------------------------------------------------------------------
#-------------------------Candle--------------Candle-----------------Candle--------------
#----------------------------------------------------------------------------------------

test1 = sps.kendalltau(X1_50, Y1_50)
test2 = sps.kendalltau(X1_100, Y1_100)
test3 = scipy.stats.kendalltau(X2_50, Y2_50)
test4= scipy.stats.kendalltau(X2_100, Y2_100)
test5 = scipy.stats.kendalltau(X3_50, Y3_50)
test6= scipy.stats.kendalltau(X3_100, Y3_100)
print("Candle 1/2 < 𝑋^2 + 𝑌^2 < 1 : \n",test1.pvalue, "\n", test2.pvalue, "\n")
print("Candle X~R[-1;1] Y~R[-1;1] : \n",test3.pvalue, "\n", test4.pvalue, "\n")
print("Candle 4 круга : \n",test5.pvalue, "\n", test6.pvalue, "\n", "\n")

#----------------------------------------------------------------------------------------
#-------------------------MGC--------------MGC-----------------MGC-----------------------
#----------------------------------------------------------------------------------------

test1 = scipy.stats.multiscale_graphcorr(np.array(X1_50), np.array(Y1_50))
test2 = scipy.stats.multiscale_graphcorr(np.array(X1_100), np.array(Y1_100))
test3 = scipy.stats.multiscale_graphcorr(np.array(X2_50), np.array(Y2_50))
test4= scipy.stats.multiscale_graphcorr(np.array(X2_100), np.array(Y2_100))
test5 = scipy.stats.multiscale_graphcorr(np.array(X3_50), np.array(Y3_50))
test6= scipy.stats.multiscale_graphcorr(np.array(X3_100), np.array(Y3_100))
print("MGC 1/2 < 𝑋^2 + 𝑌^2 < 1 : \n",test1.pvalue, "\n", test2.pvalue, "\n")
print("MGC X~R[-1;1] Y~R[-1;1] : \n",test3.pvalue, "\n", test4.pvalue, "\n")
print("MGC 4 круга : \n",test5.pvalue, "\n", test6.pvalue, "\n", "\n")

#----------------------------------------------------------------------------------------
#-------------------------HHG--------------HHG-----------------HHG-----------------------
#----------------------------------------------------------------------------------------

test1 = hyppo.ksample.KSample('HHG').test(np.array(X1_50), np.array(Y1_50))
test2 = hyppo.ksample.KSample('HHG').test(np.array(X1_100), np.array(Y1_100))
test3 = hyppo.ksample.KSample('HHG').test(np.array(X2_50), np.array(Y2_50))
test4= hyppo.ksample.KSample('HHG').test(np.array(X2_100), np.array(Y2_100))
test5 = hyppo.ksample.KSample('HHG').test(np.array(X3_50), np.array(Y3_50))
test6= hyppo.ksample.KSample('HHG').test(np.array(X3_100), np.array(Y3_100))
print("HHG 1/2 < 𝑋^2 + 𝑌^2 < 1 : \n",test1.pvalue, "\n", test2.pvalue, "\n")
print("HHG X~R[-1;1] Y~R[-1;1] : \n",test3.pvalue, "\n", test4.pvalue, "\n")
print("HHG 4 круга : \n",test5.pvalue, "\n",test6.pvalue, "\n")
# Out:
# Candle 1/2 < 𝑋^2 + 𝑌^2 < 1 :
#  0.7825171084615992
#  0.7342290947248737
#
# Candle X~R[-1;1] Y~R[-1;1] :
#  0.379775474840949
#  0.8255747200488175
#
# Candle 4 круга :
#  0.23822104702538338
#  0.36844428764563175
#
# MGC 1/2 < 𝑋^2 + 𝑌^2 < 1 :
#  0.000999000999000999
#  0.000999000999000999
#
# MGC X~R[-1;1] Y~R[-1;1] :
#  0.6453546453546454
#  0.3906093906093906
#
# MGC 4 круга :
#  0.7822177822177823
#  0.15184815184815184
#
# HHG 1/2 < 𝑋^2 + 𝑌^2 < 1 :
#  0.08691308691308691
#  0.6113886113886113
#
# HHG X~R[-1;1] Y~R[-1;1] :
#  0.955044955044955
#  0.1848151848151848
#
# HHG 4 круга :
#  0.3876123876123876
#  0.3936063936063936

# %% [markdown]
# Задача №3

# %%
import scipy
import numpy as np
import random
import pandas as pd
import seaborn as sns
import scipy.stats as sps
import matplotlib.pyplot as plt
import math
from scipy.stats import bws_test


x = np.random.exponential(1, 100)
y = np.random.exponential(1, 100)
z = np.random.exponential(1, 100)

u = []
v = []
w = []
for i in range(100):
    u.append(2*x[i] + 0.4*y[i])
    v.append(0.5*x[i] - y[i]  + 0.5*z[i])
    w.append(x[i] + 4*y[i]  + z[i])
    
data = {'X': x,
        'Y': y,
        'Z': z,
        'U': u,
        'V': v,
        'W': w
        }
#print(data)
df = pd.DataFrame(data, columns=['X','Y', 'Z', 'U', 'V', 'W'])

df.corr()

sns.heatmap(df.corr() , annot= True)
# Out:
# <Axes: >

# %%
import hyppo
import scipy
import numpy as np
import random
import scipy.stats as sps
import matplotlib.pyplot as plt
import math
from scipy.stats import bws_test
pi = math.pi

#Делаем Кольцо
phi1_50 = np.random.uniform(0, 2*pi, 50)
phi1_100 = np.random.uniform(0, 2*pi, 100)

r1_50 = np.random.uniform(1/math.sqrt(2), 1, 50)
r1_100 = np.random.uniform(1/math.sqrt(2), 1, 100)

X1_50 = []
X3_50 = []
X1_100 = []
X3_100 = []
Y1_50 = []
Y3_50 = []
Y1_100 = []
Y3_100 = []

for i in range(50):
    X1_50.append(r1_50[i]*math.cos(phi1_50[i]))
    Y1_50.append(r1_50[i]*math.sin(phi1_50[i]))

for i in range(100):
    X1_100.append(r1_100[i]*math.cos(phi1_100[i]))
    Y1_100.append(r1_100[i]*math.sin(phi1_100[i]))
#Создаём Квадрат
X2_50 = np.random.uniform(-1, 1, 50)
X2_100 = np.random.uniform(-1, 1, 100)
Y2_50 = np.random.uniform(-1, 1, 50)
Y2_100 = np.random.uniform(-1, 1, 100)

#Создаём 4 круга
for i in range(50):
    fl = random.randint(1, 2)
    flx = pow(-1, fl)
    fl = random.randint(1, 2)
    fly = pow(-1, fl)
    phi1_50 = np.random.uniform(0, 2*pi)
    r1_50 = np.random.uniform(0, 1/2)
    X3_50.append(r1_50*math.cos(phi1_50)+ flx)
    Y3_50.append(r1_50*math.sin(phi1_50)+ fly)

for i in range(100):
    fl = random.randint(1, 2)
    flx = pow(-1, fl)
    fl = random.randint(1, 2)
    fly = pow(-1, fl)
    phi1_100 = np.random.uniform(0, 2*pi)
    r1_100 = np.random.uniform(0, 1/2)
    X3_100.append(r1_100*math.cos(phi1_100) + flx)
    Y3_100.append(r1_100*math.sin(phi1_100)+ fly)


plt.scatter(X1_100, Y1_100)
