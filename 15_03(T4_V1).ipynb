# %% [markdown]
# Задача №1

# %%
from numpy.distutils.fcompiler import pg
from sklearn.linear_model import LinearRegression
import scipy
import numpy as np
import random
import sklearn
import pandas as pd
import seaborn as sns
import scipy.stats as sps
import matplotlib.pyplot as plt
import math
from scipy.stats import bws_test
from sklearn import linear_model 


X_10 = np.random.uniform(0, 1, 10)
X_100 = np.random.uniform(0, 1, 100)
X_1000 = np.random.uniform(0, 1, 1000)

Y1_10 = []
Y1_100 = []
Y1_1000 = []

Y2_10 = []
Y2_100 = []
Y2_1000 = []

Y3_10 = []
Y3_100 = []
Y3_1000 = []

s1 = 0.1
s2 = 1
s3 = 3

eps1_10 = np.random.normal(0, s1, 10)
eps2_10 = np.random.normal(0, s2, 10)
eps3_10 = np.random.normal(0, s3, 10)

eps1_100 = np.random.normal(0, s1, 100)
eps2_100 = np.random.normal(0, s2, 100)
eps3_100 = np.random.normal(0, s3, 100)

eps1_1000 = np.random.normal(0, s1, 1000)
eps2_1000 = np.random.normal(0, s2, 1000)
eps3_1000 = np.random.normal(0, s3, 1000)

for i in range(10):
    Y1_10.append(X_10[i] + eps1_10[i])
    Y2_10.append(X_10[i] + eps2_10[i])
    Y3_10.append(X_10[i] + eps3_10[i])

for i in range(100):
    Y1_100.append(X_100[i] + eps1_100[i])
    Y2_100.append(X_100[i] + eps2_100[i])
    Y3_100.append(X_100[i] + eps3_100[i])

for i in range(1000):
    Y1_1000.append(X_1000[i] + eps1_1000[i])
    Y2_1000.append(X_1000[i] + eps2_1000[i])
    Y3_1000.append(X_1000[i] + eps3_1000[i])


# print("X_10: \n", X_10, " \n")
# print("\nY1_10: \n", Y1_10)

A_10 = np.vstack([np.array(X_10), np.ones(len(np.array(X_10)))]).T
A_100 = np.vstack([np.array(X_100), np.ones(len(np.array(X_100)))]).T
A_1000 = np.vstack([np.array(X_1000), np.ones(len(X_1000))]).T

# M1 = []
# M2 = []
# M3 = []
# C1 = []
# C2 = []
# C3 = []



#----------------------------------------------------------------------------------------
#-------------------------Y_1--------------Y_1-----------------Y_1-----------------------
#----------------------------------------------------------------------------------------
n=10
lin_model = sps.linregress(X_10, Y1_10)
m1, c1 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a1_conf = sps.t.interval(0.95, df = n-2, loc=m1, scale=a_err)
b1_conf = sps.t.interval(0.95, df = n-2, loc=c1, scale=b_err)

lin_model = sps.linregress(X_10, Y2_10)
m2, c2 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a2_conf = sps.t.interval(0.95, df = n-2, loc=m2, scale=a_err)
b2_conf = sps.t.interval(0.95, df = n-2, loc=c2, scale=b_err)


lin_model = sps.linregress(X_10, Y3_10)
m3, c3 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a3_conf = sps.t.interval(0.95, df = n-2, loc=m3, scale=a_err)
b3_conf = sps.t.interval(0.95, df = n-2, loc=c3, scale=b_err)


# m1, c1 = np.linalg.lstsq(A_10, np.array(Y1_10), rcond=None)[0]
# m2, c2 = np.linalg.lstsq(A_10, np.array(Y2_10), rcond=None)[0]
# m3, c3 = np.linalg.lstsq(A_10, np.array(Y3_10), rcond=None)[0]



_= plt.plot(X_10, Y1_10, 'o', label='1_10', markersize=10)
_ = plt.plot(X_10, m1*X_10 + c1, 'r', label='Fitted line')
_ = plt.plot(X_10, a1_conf[0]*X_10 + b1_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_10, a1_conf[1]*X_10 + b1_conf[1], 'g', label='Fitted line-')
_= plt.plot(0.5, m1*0.5 + c1, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm1 = ", m1, "\nc1 = ", c1)
print("Прогноз для x = 0.5 – ", m1*0.5 + c1)
print("Прогноз для x = 2 – ", m1*2 + c1)
print("Прогноз для x = 25 – ", m1*25 + c1)
print(f"m1 = {m1:0.4f}, αlpha=5% [{a1_conf[0]:0.4f} - {a1_conf[1]:0.4f}]")
print(f"c1 = {c1:0.4f}, αlpha=5% [{b1_conf[0]:0.4f} - {b1_conf[1]:0.4f}]")



_= plt.plot(X_10, Y2_10, 'o', label='2_10', markersize=10)
_ = plt.plot(X_10, m2*X_10 + c2, 'r', label='Fitted line')
_ = plt.plot(X_10, a2_conf[0]*X_10 + b2_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_10, a2_conf[1]*X_10 + b2_conf[1], 'g', label='Fitted li-e=')
_= plt.plot(0.5, m2*0.5 + c2, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm2 = ", m2, "\nc2 = ", c2)
print("Прогноз для x = 0.5 – ", m2*0.5 + c2)
print("Прогноз для x = 2 – ", m2*2 + c2)
print("Прогноз для x = 25 – ", m2*25 + c2)
print(f"m2 = {m2:0.4f}, αlpha=5% [{a2_conf[0]:0.4f} - {a2_conf[1]:0.4f}]")
print(f"c2 = {c2:0.4f}, αlpha=5% [{b2_conf[0]:0.4f} - {b2_conf[1]:0.4f}]")

_= plt.plot(X_10, Y3_10, 'o', label='3_10', markersize=10)
_ = plt.plot(X_10, m3*X_10 + c3, 'r', label='Fitted line')
_ = plt.plot(X_10, a3_conf[0]*X_10 + b3_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_10, a3_conf[1]*X_10 + b3_conf[1], 'g', label='Fitted line-')
_= plt.plot(0.5, m3*0.5 + c3, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm3 = ", m3, "\nc3 = ", c3)
print("Прогноз для x = 0.5 – ", m3*0.5 + c3)
print("Прогноз для x = 2 – ", m3*2 + c3)
print("Прогноз для x = 25 – ", m3*25 + c3)
print(f"m3 = {m3:0.4f}, αlpha=5% [{a3_conf[0]:0.4f} - {a3_conf[1]:0.4f}]")
print(f"c3 = {c3:0.4f}, αlpha=5% [{b3_conf[0]:0.4f} - {b3_conf[1]:0.4f}]")

#----------------------------------------------------------------------------------------
#-------------------------Y_2--------------Y_2-----------------Y_2-----------------------
#----------------------------------------------------------------------------------------

n=100
lin_model = sps.linregress(X_100, Y1_100)
m1, c1 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a1_conf = sps.t.interval(0.95, df = n-2, loc=m1, scale=a_err)
b1_conf = sps.t.interval(0.95, df = n-2, loc=c1, scale=b_err)

lin_model = sps.linregress(X_100, Y2_100)
m2, c2 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a2_conf = sps.t.interval(0.95, df = n-2, loc=m2, scale=a_err)
b2_conf = sps.t.interval(0.95, df = n-2, loc=c2, scale=b_err)


lin_model = sps.linregress(X_100, Y3_100)
m3, c3 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a3_conf = sps.t.interval(0.95, df = n-2, loc=m3, scale=a_err)
b3_conf = sps.t.interval(0.95, df = n-2, loc=c3, scale=b_err)



_= plt.plot(X_100, Y1_100, 'o', label='1_100', markersize=3)
_ = plt.plot(X_100, m1*X_100 + c1, 'r', label='Fitted line')
_ = plt.plot(X_100, a1_conf[0]*X_100 + b1_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_100, a1_conf[1]*X_100 + b1_conf[1], 'g', label='Fitted line-')
_= plt.plot(0.5, m1*0.5 + c1, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm1 = ", m1, "\nc1 = ", c1)
print("Прогноз для x = 0.5 – ", m1*0.5 + c1)
print("Прогноз для x = 2 – ", m1*2 + c1)
print("Прогноз для x = 25 – ", m1*25 + c1)
print(f"m1 = {m1:0.4f}, αlpha=5% [{a1_conf[0]:0.4f} - {a1_conf[1]:0.4f}]")
print(f"c1 = {c1:0.4f}, αlpha=5% [{b1_conf[0]:0.4f} - {b1_conf[1]:0.4f}]")

_= plt.plot(X_100, Y2_100, 'o', label='2_100', markersize=3)
_ = plt.plot(X_100, m2*X_100 + c2, 'r', label='Fitted line')
_ = plt.plot(X_100, a2_conf[0]*X_100 + b2_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_100, a2_conf[1]*X_100 + b2_conf[1], 'g', label='Fitted li-e=')
_= plt.plot(0.5, m2*0.5 + c2, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm2 = ", m2, "\nc2 = ", c2)
print("Прогноз для x = 0.5 – ", m2*0.5 + c2)
print("Прогноз для x = 2 – ", m2*2 + c2)
print("Прогноз для x = 25 – ", m2*25 + c2)
print(f"m2 = {m2:0.4f}, αlpha=5% [{a2_conf[0]:0.4f} - {a2_conf[1]:0.4f}]")
print(f"c2 = {c2:0.4f}, αlpha=5% [{b2_conf[0]:0.4f} - {b2_conf[1]:0.4f}]")


_= plt.plot(X_100, Y3_100, 'o', label='3_100', markersize=3)
_ = plt.plot(X_100, m3*X_100 + c3, 'r', label='Fitted line')
_ = plt.plot(X_100, a3_conf[0]*X_100 + b3_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_100, a3_conf[1]*X_100 + b3_conf[1], 'g', label='Fitted line-')
_= plt.plot(0.5, m3*0.5 + c3, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm3 = ", m3, "\nc3 = ", c3)
print("Прогноз для x = 0.5 – ", m3*0.5 + c3)
print("Прогноз для x = 2 – ", m3*2 + c3)
print("Прогноз для x = 25 – ", m3*25 + c3)
print(f"m3 = {m3:0.4f}, αlpha=5% [{a3_conf[0]:0.4f} - {a3_conf[1]:0.4f}]")
print(f"c3 = {c3:0.4f}, αlpha=5% [{b3_conf[0]:0.4f} - {b3_conf[1]:0.4f}]")

#----------------------------------------------------------------------------------------
#-------------------------Y_3--------------Y_3-----------------Y_3-----------------------
#----------------------------------------------------------------------------------------

n=1000
lin_model = sps.linregress(X_1000, Y1_1000)
m1, c1 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a1_conf = sps.t.interval(0.95, df = n-2, loc=m1, scale=a_err)
b1_conf = sps.t.interval(0.95, df = n-2, loc=c1, scale=b_err)

lin_model = sps.linregress(X_1000, Y2_1000)
m2, c2 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a2_conf = sps.t.interval(0.95, df = n-2, loc=m2, scale=a_err)
b2_conf = sps.t.interval(0.95, df = n-2, loc=c2, scale=b_err)


lin_model = sps.linregress(X_1000, Y3_1000)
m3, c3 = lin_model.slope, lin_model.intercept
a_err, b_err = lin_model.stderr, lin_model.intercept_stderr
a3_conf = sps.t.interval(0.95, df = n-2, loc=m3, scale=a_err)
b3_conf = sps.t.interval(0.95, df = n-2, loc=c3, scale=b_err)


_= plt.plot(X_1000, Y1_1000, 'o', label='1_1000', markersize=1)
_ = plt.plot(X_1000, m1*X_1000 + c1, 'r', label='Fitted line')
_ = plt.plot(X_1000, a1_conf[0]*X_1000 + b1_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_1000, a1_conf[1]*X_1000 + b1_conf[1], 'g', label='Fitted line-')
_= plt.plot(0.5, m1*0.5 + c1, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm1 = ", m1, "\nc1 = ", c1)
print("Прогноз для x = 0.5 – ", m1*0.5 + c1)
print("Прогноз для x = 2 – ", m1*2 + c1)
print("Прогноз для x = 25 – ", m1*25 + c1)
print(f"m1 = {m1:0.4f}, αlpha=5% [{a1_conf[0]:0.4f} - {a1_conf[1]:0.4f}]")
print(f"c1 = {c1:0.4f}, αlpha=5% [{b1_conf[0]:0.4f} - {b1_conf[1]:0.4f}]")

_= plt.plot(X_1000, Y2_1000, 'o', label='2_1000', markersize=1)
_ = plt.plot(X_1000, m2*X_1000 + c2, 'r', label='Fitted line')
_ = plt.plot(X_1000, a2_conf[0]*X_1000 + b2_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_1000, a2_conf[1]*X_1000 + b2_conf[1], 'g', label='Fitted li-e=')
_= plt.plot(0.5, m2*0.5 + c2, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm2 = ", m2, "\nc2 = ", c2)
print("Прогноз для x = 0.5 – ", m2*0.5 + c2)
print("Прогноз для x = 2 – ", m2*2 + c2)
print("Прогноз для x = 25 – ", m2*25 + c2)
print(f"m2 = {m2:0.4f}, αlpha=5% [{a2_conf[0]:0.4f} - {a2_conf[1]:0.4f}]")
print(f"c2 = {c2:0.4f}, αlpha=5% [{b2_conf[0]:0.4f} - {b2_conf[1]:0.4f}]")


_= plt.plot(X_1000, Y3_1000, 'o', label='3_1000', markersize=1)
_ = plt.plot(X_1000, m3*X_1000 + c3, 'r', label='Fitted line')
_ = plt.plot(X_1000, a3_conf[0]*X_1000 + b3_conf[0], 'g', label='Fitted line+')
_ = plt.plot(X_1000, a3_conf[1]*X_1000 + b3_conf[1], 'g', label='Fitted line-')
_= plt.plot(0.5, m3*0.5 + c3, '*g', label='x = 0.5', markersize=10)
_ = plt.legend()
plt.show()

print("\nm3 = ", m3, "\nc3 = ", c3)
print("Прогноз для x = 0.5 – ", m3*0.5 + c3)
print("Прогноз для x = 2 – ", m3*2 + c3)
print("Прогноз для x = 25 – ", m3*25 + c3)
print(f"m3 = {m3:0.4f}, αlpha=5% [{a3_conf[0]:0.4f} - {a3_conf[1]:0.4f}]")
print(f"c3 = {c3:0.4f}, αlpha=5% [{b3_conf[0]:0.4f} - {b3_conf[1]:0.4f}]")



#--------------------------------------------------------
# Out:
# m1 =  1.005376309959647
# c1 =  0.011591619788570262
# Прогноз для x = 0.5 –  0.5142797747683938
# Прогноз для x = 2 –  2.0223442397078646
# Прогноз для x = 25 –  25.145999368779748
# m1 = 1.0054, αlpha=5% [0.6752 - 1.3355]
# c1 = 0.0116, αlpha=5% [-0.1414 - 0.1646]
# m2 =  1.750662936756624
# c2 =  -0.13203169935682735
# Прогноз для x = 0.5 –  0.7432997690214846
# Прогноз для x = 2 –  3.369294174156421
# Прогноз для x = 25 –  43.63454171955877
# m2 = 1.7507, αlpha=5% [-1.7213 - 5.2227]
# c2 = -0.1320, αlpha=5% [-1.7414 - 1.4773]
# m3 =  -3.144231895101142
# c3 =  2.2179495865505974
# Прогноз для x = 0.5 –  0.6458336390000263
# Прогноз для x = 2 –  -4.070514203651687
# Прогноз для x = 25 –  -76.38784779097794
# m3 = -3.1442, αlpha=5% [-13.9018 - 7.6134]
# c3 = 2.2179, αlpha=5% [-2.7685 - 7.2044]
# m1 =  1.0166449014012915
# c1 =  0.006581739194775338
# Прогноз для x = 0.5 –  0.5149041898954211
# Прогноз для x = 2 –  2.0398715419973583
# Прогноз для x = 25 –  25.422704274227062
# m1 = 1.0166, αlpha=5% [0.9491 - 1.0842]
# c1 = 0.0066, αlpha=5% [-0.0333 - 0.0465]
# m2 =  0.45769759886761163
# c2 =  0.2588533531549472
# Прогноз для x = 0.5 –  0.487702152588753
# Прогноз для x = 2 –  1.1742485508901703
# Прогноз для x = 25 –  11.701293324845238
# m2 = 0.4577, αlpha=5% [-0.2850 - 1.2004]
# c2 = 0.2589, αlpha=5% [-0.1797 - 0.6974]
# m3 =  1.2958600376860145
# c3 =  -0.23234536597417482
# Прогноз для x = 0.5 –  0.41558465286883245
# Прогноз для x = 2 –  2.359374709397854
# Прогноз для x = 25 –  32.164155576176185
# m3 = 1.2959, αlpha=5% [-0.9465 - 3.5382]
# c3 = -0.2323, αlpha=5% [-1.5564 - 1.0918]
# m1 =  1.0252285085082542
# c1 =  -0.010642545002636616
# Прогноз для x = 0.5 –  0.5019717092514905
# Прогноз для x = 2 –  2.039814472013872
# Прогноз для x = 25 –  25.62007016770372
# m1 = 1.0252, αlpha=5% [1.0035 - 1.0469]
# c1 = -0.0106, αlpha=5% [-0.0231 - 0.0018]
# m2 =  1.010281744400559
# c2 =  -0.042628259435656846
# Прогноз для x = 0.5 –  0.46251261276462263
# Прогноз для x = 2 –  1.977935229365461
# Прогноз для x = 25 –  25.214415350578317
# m2 = 1.0103, αlpha=5% [0.8019 - 1.2186]
# c2 = -0.0426, αlpha=5% [-0.1622 - 0.0769]
# m3 =  1.0062735697310068
# c3 =  -0.032258807850652105
# Прогноз для x = 0.5 –  0.4708779770148513
# Прогноз для x = 2 –  1.9802883316113615
# Прогноз для x = 25 –  25.124580435424516
# m3 = 1.0063, αlpha=5% [0.3796 - 1.6329]
# c3 = -0.0323, αlpha=5% [-0.3919 - 0.3273]

# %% [markdown]
# Задача №2

# %%
from sklearn.linear_model import LinearRegression
import scipy
import numpy as np
import statsmodels.api as sm
import random
import sklearn
import pandas as pd
import seaborn as sns
import scipy.stats as sps
import matplotlib.pyplot as plt
import math
from scipy.stats import bws_test
from sklearn import linear_model 
import seaborn as sn
import pingouin as pg

# X_100 = np.random.uniform(0, 1, 100)
# X_1000 = np.random.uniform(0, 1, 1000)
# X_10000 = np.random.uniform(0, 1, 10000)
# 
# eps_100 = np.random.normal(0,1,100)
# eps_1000 = np.random.normal(0,1,1000)
# eps_10000 = np.random.normal(0,1,10000)
# 
# Y3_100 = []
# Y5_100 = []
# Y10_100 = []
# Y3_1000 = []
# Y5_1000 = []
# Y10_1000 = []
# Y3_10000 = []
# Y5_10000 = []
# Y10_10000 = []

# m3 = 3
# m5 = 5
# m10 = 10
# # for i in range(100):
# #     temp = 0
# #     for j in range(m3):
# #         temp += j*(X_100[i]**j) + eps_100[i]
# #     Y3_100.append(temp)
# #     temp = 0
# #     for j in range(m5):
# #         temp += j*(X_100[i]**j) + eps_100[i]
# #     Y5_100.append(temp)
# #     temp = 0
# #     for j in range(m10):
# #         temp += j*(X_100[i]**j) + eps_100[i]
# #     Y10_100.append(temp)
# # 
# # for i in range(1000):
# #     temp = 0
# #     for j in range(m3):
# #         temp += j*(X_1000[i]**j) + eps_1000[i]
# #     Y3_1000.append(temp)
# #     temp = 0
# #     for j in range(m5):
# #         temp += j*(X_1000[i]**j) + eps_1000[i]
# #     Y5_1000.append(temp)
# #     temp = 0
# #     for j in range(m10):
# #         temp += j*(X_1000[i]**j) + eps_1000[i]
# #     Y10_1000.append(temp)
# # 
# # for i in range(10000):
# #     temp = 0
# #     for j in range(m3):
# #         temp += j*(X_10000[i]**j) + eps_10000[i]
# #     Y3_10000.append(temp)
# #     temp = 0
# #     for j in range(m5):
# #         temp += j*(X_10000[i]**j) + eps_10000[i]
# #     Y5_10000.append(temp)
# #     temp = 0
# #     for j in range(m10):
# #         temp += j*(X_10000[i]**j) + eps_10000[i]
# #     Y10_10000.append(temp)
# 
# 
# #model = sm.OLS(Y3_100, X_100).fit()
# 
# 
# 
# #----------------------------------------------------------------------------------------
# #-------------------------Y_100--------------Y_100-----------------Y_100-----------------
# #----------------------------------------------------------------------------------------
# X = []
# Y = []
# n = 100
# X = np.random.uniform(0,1, n)
# X0 = np.ones(n)
# X1 = X
# X2 = X**2
# X3 = X**3
# X4 = X**4
# X5 = X**5
# X6 = X**6
# X7 = X**7
# X8 = X**8
# X9 = X**9
# X10 = X**10
# 
# 
# Y_3 = 5 * (X0 + X1 + X2 + X3) + eps
# 
# # Y_3 = 4*eps + X1 + 2*X2 + 3*X3
# Y_5 = 6*eps + X1 + 2*X2 + 3*X3 + 4*X4 + 5*X5
# Y_10 = 11*eps + X1 + 2*X2 + 3*X3 + 4*X4 + 5*X5 + 6*X6 + 7*X7 + 8*X8 + 9*X9 + 10*X10
# 
# # X_3 = np.matrix([ X1, X2, X3]).transpose()
# X_3 = np.matrix([X0, X1, X2, X3]).transpose()
# X_5 = np.matrix([ X1, X2, X3, X4, X5]).transpose()
# X_10 = np.matrix([ X1, X2, X3, X4, X5, X6, X7, X8, X9, X10]).transpose()
# 
# mod = sm.OLS(Y_3, X_3)
# res = mod.fit()
# b = res.params
# print("\nCoefficients for m = 3: ", b)
# Y_hat3 = b[0] * X0 + b[1] * X1 + b[2] * X2 + b[3] * X3
# print('BIC = ',res.bic)
# print('AIC = ',res.aic)
# print('R2_adj = ',res.rsquared_adj)
# 
# plt.scatter(X1, Y_3)
# plt.plot(X1, Y_hat3, color = 'red')
# plt.show()
# 
# # Xmat3 = [X1, X2, X3]
# # Xmat3 = np.array(Xmat3)
# # Xmat3 = Xmat3.T
# # Xmat3 = pd.DataFrame(Xmat3)
# # # Xmat3m = pd.concat([Xmat3], axis=1)
# # # m.set_axis(['X','X^2','X^3'], axis=1, inplace=True)
# # pg.pcorr(Xmat3)
# # sn.heatmap(pg.pcorr(pg.pcorr(Xmat3)), annot = True)
# # plt.show()
# 
# 


n_values = [100, 1000, 10000]
for i, n in enumerate(n_values):
    print('n = ', n)
    X = []
    Y = []
    X = np.random.uniform(0,1,n)
    X.sort()
    # X0 = np.ones(n)
    X1 = X
    X2 = X**2
    X3 = X**3
    X4 = X**4
    X5 = X**5
    X6 = X**6
    X7 = X**7
    X8 = X**8
    X9 = X**9
    X10 = X**10
    eps = np.random.normal(0,1,n)

    Y_3 = 4*eps + X1 + 2*X2 + 3*X3
    Y_5 = 6*eps + X1 + 2*X2 + 3*X3 + 4*X4 + 5*X5
    Y_10 = 11*eps + X1 + 2*X2 + 3*X3 + 4*X4 + 5*X5 + 6*X6 + 7*X7 + 8*X8 + 9*X9 + 10*X10
    X_3 = np.matrix([ X1, X2, X3]).transpose()
    X_5 = np.matrix([ X1, X2, X3, X4, X5]).transpose()
    X_10 = np.matrix([ X1, X2, X3, X4, X5, X6, X7, X8, X9, X10]).transpose()
# ---------------------------------------------------------------------------------------------
# ----------------------------------- m = 3 ---------------------------------------------------  
# ---------------------------------------------------------------------------------------------

    res = sm.OLS(Y_3, X_3).fit()
    b = res.params
    print("\nCoefficients for m = 3: ", b)
    Y_hat3 = b[0] * X1 + b[1] * X2 + b[2] * X3
    print('BIC = ',res.bic)
    print('AIC = ',res.aic)
    print('R2_adj = ',res.rsquared_adj)
    
    plt.scatter(X1, Y_3)
    plt.plot(X1, Y_hat3, color = 'red')
    plt.show()
    
    Xmat3 = pd.DataFrame(X_3)
    Xmat3m = pd.concat([Xmat3], axis=1)
    pg.pcorr(Xmat3)
    sn.heatmap(pg.pcorr(pg.pcorr(Xmat3)), annot = True)
    plt.show()
    
# ---------------------------------------------------------------------------------------------
# ----------------------------------- m = 5 ---------------------------------------------------  
# ---------------------------------------------------------------------------------------------
    
    res = sm.OLS(Y_5, X_5).fit()
    b = res.params
    print("\nCoefficients for m = 5: ", b)
    Y_hat5 = b[0] * X1 + b[1] * X2 + b[2] * X3 + b[3] * X4 + b[4] * X5
    print('BIC = ',res.bic)
    print('AIC = ',res.aic)
    print('R2_adj = ',res.rsquared_adj)
    
    plt.scatter(X1, Y_5)
    plt.plot(X1, Y_hat5, color = 'red')
    plt.show()
    
    Xmat5 = [X1, X2, X3, X4, X5]
    Xmat5 = np.array(Xmat5)
    Xmat5 = Xmat5.T
    Xmat5 = pd.DataFrame(Xmat5)
    m = pd.concat([Xmat5], axis=1)
    pg.pcorr(m)
    sn.heatmap(pg.pcorr(m), annot = True)
    plt.show()
# ---------------------------------------------------------------------------------------------
# ----------------------------------- m = 10 --------------------------------------------------
# ---------------------------------------------------------------------------------------------
    
    res = sm.OLS(Y_10, X_10).fit()
    b = res.params
    print("\nCoefficients for m = 10: ", b)
    Y_hat10 = b[0] * X1 + b[1] * X2 + b[2] * X3 + b[3] * X4 + b[4] * X5 + b[5] * X6 + b[6] * X7 + b[7] * X8 + b[8] * X9 + b[9] * X10
    print('BIC = ',res.bic)
    print('AIC = ',res.aic)
    print('R2_adj = ',res.rsquared_adj)
    plt.scatter(X1, Y_10)
    plt.plot(X1, Y_hat10, color = 'red')
    plt.show()
    
    Xmat10 = [X1, X2, X3, X4, X5, X6, X7, X8, X9, X10]
    Xmat10 = np.array(Xmat10)
    Xmat10 = Xmat10.T
    Xmat10 = pd.DataFrame(Xmat10)
    m = pd.concat([Xmat10], axis=1)
    pg.pcorr(m)
    sn.heatmap(pg.pcorr(m), annot = True)
    plt.show()
    
    print('1, X and X^10:')
    X_spec = np.matrix([ X1, X10]).transpose()
    Y = Y_10
    mod2 = sm.OLS(Y, X_spec)
    res2 = mod2.fit()
    q = res2.params
    Y_res = q[0] * X1 + q[1]*(X1**10)
    plt.scatter(X1, Y_10)
    plt.plot(X1, Y_res, color = 'red')
    plt.show()
    
    print('1, X, X^3 and X^9:')
    X_spec = np.matrix([ X1, X3, X9]).transpose()
    Y = Y_10
    mod2 = sm.OLS(Y, X_spec)
    res2 = mod2.fit()
    q = res2.params
    Y_res = q[0] * X1 + q[1]*(X1**3) + q[2]*(X1**9)
    plt.scatter(X1, Y_10)
    plt.plot(X1, Y_res, color = 'red')
    plt.show()
    print('BIC = ',res2.bic)
    print('AIC = ',res2.aic)
    print('R2_adj = ',res2.rsquared_adj)
# Out:
# n =  100
#
# Coefficients for m = 3:  [ 11.16864366 -45.15049111  45.18845033]
# BIC =  551.2749491700681
# AIC =  543.4594386121038
# R2_adj =  0.3483409488360407
# Coefficients for m = 5:  [   71.84996395  -488.26403084  1092.66795224 -1005.06854986
#    349.27174015]
# BIC =  636.2841842326503
# AIC =  623.2583333027098
# R2_adj =  0.5055462383600173
# Coefficients for m = 10:  [-5.16409532e+01  8.62377142e+02  5.18532468e+03 -9.60003065e+04
#   4.85520024e+05 -1.29753593e+06  2.07637238e+06 -2.00130287e+06
#   1.07031308e+06 -2.43305358e+05]
# BIC =  771.3683350068815
# AIC =  745.3166331470005
# R2_adj =  0.6802545345928006
# 1, X and X^10:
# 1, X, X^3 and X^9:
# BIC =  758.7866539176404
# AIC =  750.971143359676
# R2_adj =  0.6388948996623959
# n =  1000
#
# Coefficients for m = 3:  [-1.65177873  9.2894256  -1.6381665 ]
# BIC =  5627.959739239332
# AIC =  5613.236473402385
# R2_adj =  0.2959566230665489
# Coefficients for m = 5:  [  -6.97512149   51.08487994 -120.69950919  146.37144914  -55.09953874]
# BIC =  6452.493480067907
# AIC =  6427.9547036729955
# R2_adj =  0.43972140436547524
# Coefficients for m = 10:  [ 6.51092379e+00 -1.17412510e+02 -5.05631224e+02  1.60875719e+04
#  -1.11702991e+05  3.85009644e+05 -7.42711711e+05  8.12022870e+05
#  -4.69585021e+05  1.11552151e+05]
# BIC =  7694.489384455848
# AIC =  7645.411831666027
# R2_adj =  0.6314535710033904
# 1, X and X^10:
# 1, X, X^3 and X^9:
# BIC =  7651.45005399142
# AIC =  7636.726788154473
# R2_adj =  0.6320909253400249
# n =  10000
#
# Coefficients for m = 3:  [1.28692769 1.52144732 3.17949234]
# BIC =  55825.008302031165
# AIC =  55803.377280915236
# R2_adj =  0.29877783203153496
# Coefficients for m = 5:  [ -0.46331014  12.29268474 -14.70284356  11.47793648   6.58954552]
# BIC =  63951.43420356209
# AIC =  63915.3825017022
# R2_adj =  0.44713025689808106
# Coefficients for m = 10:  [ 2.30114742e+01 -7.32980472e+02  9.00662109e+03 -5.79071170e+04
#   2.21409193e+05 -5.25929635e+05  7.80287112e+05 -7.01131338e+05
#   3.48344051e+05 -7.33139169e+04]
# BIC =  76117.51728755211
# AIC =  76045.41388383234
# R2_adj =  0.643243624603686
# 1, X and X^10:
# 1, X, X^3 and X^9:
# BIC =  76056.70402512809
# AIC =  76035.07300401216
# R2_adj =  0.6433629550994395

# %% [markdown]
# test
